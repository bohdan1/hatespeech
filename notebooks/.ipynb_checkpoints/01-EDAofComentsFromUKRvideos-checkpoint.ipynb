# %%
import pandas as pd

# %%
path = '../data/comments.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                            id     video_id         time          author  \
# 0  UgyhF7x3wDjb6vOmM4R4AaABAg  _k-gDXrfu-s   4 days ago  Sayana Teremok
# 1  UgzpXFHyCqR8-y3OHxx4AaABAg  _k-gDXrfu-s  2 weeks ago       Panda Pro
# 2  UgxqMgIi8KZCdmmDD4d4AaABAg  _k-gDXrfu-s  3 weeks ago   виктор шкляев
# 3  UgyQXzfwAqFj7d7aGzp4AaABAg  _k-gDXrfu-s  3 weeks ago       Scelaborg
# 4  Ugw4TNEKmVy2xLRLR-V4AaABAg  _k-gDXrfu-s  1 month ago  Garegin Nzhdeh
#
#                                                 text
# 0  И как сейчас вам ваш майдан? органы на продажу...
# 1                      Нахрена ожног 30 ром ебашить﻿
# 2                                      Россия 20:18﻿
# 3  поздно стрелять боевыми начали,надо было стрел...
# 4    Надо было беркутовцам головы позерать к ебеням﻿

# %%
len(df)
# Out:
# 36644

# %%
df.columns[3]
# Out:
# 'author'

# %%
df.groupby(['video_id']).count().sort_values(by=['id'], ascending = False)
# Out:
#                id  time  author  text
# video_id
# T6IbEIBhb8o  6099  6099    6099  6093
# zCmV4dX5tgs  3901  3901    3901  3899
# NiT0zcDA9RU  1481  1481    1481  1480
# E950t1WGiE0  1408  1408    1408  1407
# uhwtsjFbQK4  1180  1180    1180  1179
# FXCliOGt0Jc  1030  1030    1029  1029
# yjMs_vAV6S8  1009  1009    1009  1009
# xZUzfzTLD4U   912   912     912   911
# IqFdatdem64   858   858     858   856
# SwZ_LW9NsUE   813   813     813   813
# wObv3OVPk30   786   786     786   786
# IC7sx75-A0Q   720   720     720   719
# H_ToRtwlvpI   591   591     591   591
# TATn7Q207y0   512   512     512   512
# ihixlCUv3tY   449   449     449   449
# AV127gSoJxM   446   446     446   444
# XW6hWPZglv8   425   425     425   425
# AyVvGv4Seag   417   417     417   417
# K0icRY1Ae5A   361   361     361   361
# KLugDbnOhws   356   356     356   356
# 7xpI5dMsnEM   345   345     345   345
# t8u6l6BNEb0   340   340     340   340
# rngYEzRxlWU   335   335     335   335
# ...

# %%
df[df.author == 'Олежка Русский']['video_id'].nunique()
# Out:
# 1

# %%
x = dict()
for person in df.author.unique():
    x[person] =df[df.author == person]['video_id'].nunique()

# %%
import operator
sorted_x = sorted(x.items(), key=operator.itemgetter(1), reverse=True)

# %%
sorted_x
# Out:
# [('Иван Иванов', 15),
#  ('Андрей Иванов', 14),
#  ('Сергей Иванов', 12),
#  ('Александр', 12),
#  ('Саша Балохин', 12),
#  ('Неуловимый Джо', 9),
#  ('IvFrUkr', 9),
#  ('Александр Иванов', 9),
#  ('Алексей Иванов', 8),
#  ('Oleg Marchuk', 8),
#  ('Igor zerojke', 7),
#  ('иван иванов', 7),
#  ('grAnd', 7),
#  ('Иван Петров', 7),
#  ('Вася Пупкин', 7),
#  ('зинаида степанова', 7),
#  ('setdstr', 7),
#  ('Lena alyohina', 7),
#  ('Ivan Ivanov', 7),
#  ('ROMA NICHIK', 7),
#  ('Ан Рівне', 7),
#  ('Garret Bale', 6),
#  ('ан ук', 6),
#  ('Илья', 6),
#  ('Daanava', 6),
#  ('Владыка форума', 6),
#  ('ENISEI ZP', 6),
#  ('Ket T', 6),
#  ('BlatnoyValera', 6),
#  ('Pavlo Mamontov', 6),
#  ('Сергей', 6),
#  ('POROX Степанов', 6),
#  ('Олег К', 6),
#  ('Goodmanoid Che', 6),
#  ('Fartovo Рortovbly', 6),
#  ('zerownt', 6),
#  ('Леся Ярославна', 6),
#  ('Андрей Анатольевич', 6),
#  ('Andrew Liberman', 6),
#  ('Коля Куш', 6),
#  ('WQW', 6),
#  ('Oksana Ukraine', 5),
#  ('Дима А', 5),
# ...

# %%
for text in df[df.author == 'Иван Иванов'].text:
    print(text)
    print('-----------------------')
# Out:
# Батя мы тебя услышали и все сделали как ты сказал.подпись - Майдан﻿
# -----------------------
# Изумительная работа, отличный видеомонтаж. Песня неплохая, на злобу дня. Друзья, расширяйте местечковое мышление и не зацикливайтесь в одной, отдельно взятой стране. Культура, как и язык постоянно развивается. На это уходят, порой, столетия... Проявите интеллект, и сократите наш путь в Европу, хотя бы на десятилетия...﻿
# -----------------------
# и кто т оверит в эту чушь? больная страна его ее последении годы независимости нет страну урина и не было﻿
# -----------------------
# Слов нет  маразм﻿
# -----------------------
# вышли пидары ущербные﻿
# -----------------------
# ...

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/bandrusyak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/bandrusyak/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
sentence =  df[(df.author == 'Иван Иванов') & (df.id =='Ugi6ohMVoexb1ngCoAEC')].text.values[0]

# %%
sentence
# Out:
# 'Батя мы тебя услышали и все сделали как ты сказал.подпись - Майдан\ufeff'

# %%
tokens = nltk.word_tokenize(sentence)

# %%
tokens
# Out:
# ['Батя',
#  'мы',
#  'тебя',
#  'услышали',
#  'и',
#  'все',
#  'сделали',
#  'как',
#  'ты',
#  'сказал.подпись',
#  '-',
#  'Майдан\ufeff']

# %%
tagged = nltk.pos_tag(tokens)

# %%
tagged
# Out:
# [('Батя', 'JJ'),
#  ('мы', 'NNP'),
#  ('тебя', 'NNP'),
#  ('услышали', 'NNP'),
#  ('и', 'NNP'),
#  ('все', 'NNP'),
#  ('сделали', 'NNP'),
#  ('как', 'NNP'),
#  ('ты', 'NNP'),
#  ('сказал.подпись', 'NNP'),
#  ('-', ':'),
#  ('Майдан\ufeff', 'NN')]

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

# %%
stemmer.stem("нацистка")
# Out:
# 'нацистк'

# %%
bad_words = open('../data/bad_words.txt').read()

# %%
hate_words = open('../data/hate_words.txt').read()

# %%
hate_words = hate_words.split('\n')

# %%
bad_words = bad_words.split(', ')

# %%
count = 0
error_count =0 
for sentence in df.text:
    try:
        tokens = nltk.word_tokenize(sentence)
    except TypeError:
        error_count += 1
    if any(bad_word in tokens for bad_word in hate_words):
        count += 1

# %%
print(count)
# Out:
# 205

# %%
error_count
# Out:
# 32

# %%
len(df)
# Out:
# 36644

# %%
banned_words =  open('../data/banned_words.txt').read()

# %%
banned_words
# Out:
# 'говновоз.рф\nдевство.рф\nговноед.рф\nговномер.рф\nговномес.рф\nговнецо.рф\nговнистый.рф\nговниться.рф\nговённый.рф\nговнюк.рф\nговно.рф\nпиздомудство.рф\nедритявкорень.рф\nпиздецвсему.рф\nпиздецовый.рф\nдерьмовый.рф\nоднохуйственно.рф\nдвужопник.рф\nпиздийволос.рф\nпиздопротивный.рф\nпиздывломить.рф\nмудозвон.рф\nмудотяпство.рф\nсхуевудушу.рф\nвпендюрить.рф\nнивпизду.рф\nвпиздюлиться.рф\nвыпиздюлиться.рф\nвпиздюлить.рф\nвыпиздюлить.рф\nвпиздюриться.рф\nвыпиздюриться.рф\nвыпиздяриться.рф\nвпиздюрить.рф\nвпиздярить.рф\nвыпиздюрить.рф\nвыпиздярить.рф\nвпиздиться.рф\nвыпиздяшиться.рф\nвпиздяшиться.рф\nвпиздячиться.рф\nвыпиздячиться.рф\nвыпиздиться.рф\nвыпиздяшить.рф\nвпиздяшить.рф\nвыпиздить.рф\nвыпиздячить.рф\nвпиздячить.рф\nвпиздить.рф\nвпиздрониться.рф\nвпиздронить.рф\nвыпиздошиться.рф\nвпиздошиться.рф\nвыпиздошить.рф\nвпиздошить.рф\nвпиздякнуть.рф\nвпизду.рф\nвздрочиться.рф\nвздрочить.рф\nвздрючить.рф\nвлындить.рф\nвыдрочиться.рф\nвыдрочить.рф\nвыдрючиться.рф\nвыдрючить.рф\nохеревши
# ...

# %%
banned_words = banned_words.split('\n')

# %%
x = []
for word in banned_words:
    a = word.replace('.рф', '')
    x.append(a)

# %%
x
# Out:
# ['говновоз',
#  'девство',
#  'говноед',
#  'говномер',
#  'говномес',
#  'говнецо',
#  'говнистый',
#  'говниться',
#  'говённый',
#  'говнюк',
#  'говно',
#  'пиздомудство',
#  'едритявкорень',
#  'пиздецвсему',
#  'пиздецовый',
#  'дерьмовый',
#  'однохуйственно',
#  'двужопник',
#  'пиздийволос',
#  'пиздопротивный',
#  'пиздывломить',
#  'мудозвон',
#  'мудотяпство',
#  'схуевудушу',
#  'впендюрить',
#  'нивпизду',
#  'впиздюлиться',
#  'выпиздюлиться',
#  'впиздюлить',
#  'выпиздюлить',
#  'впиздюриться',
#  'выпиздюриться',
#  'выпиздяриться',
#  'впиздюрить',
#  'впиздярить',
#  'выпиздюрить',
#  'выпиздярить',
#  'впиздиться',
#  'выпиздяшиться',
#  'впиздяшиться',
#  'впиздячиться',
#  'выпиздячиться',
#  'выпиздиться',
#  'выпиздяшить',
#  'впиздяшить',
#  'выпиздить',
#  'выпиздячить',
#  'впиздячить',
#  'впиздить',
#  'впиздрониться',
#  'впиздронить',
#  'выпиздошиться',
#  'впиздошиться',
#  'выпиздошить',
#  'впиздошить',
#  'впиздякнуть',
#  'впизду',
# ...

# %%
count = 0
error_count =0 
for sentence in df.text:
    try:
        tokens = nltk.word_tokenize(sentence)
    except TypeError:
        error_count += 1
    '''for bad_word in x:
        if bad_word in tokens:
            print(bad_word, '|', sentence)
            print('--------------------------------------------')'''
    good = True
    if any(bad_word in tokens for bad_word in x) or any(bad_word in tokens for bad_word in bad_words) or any(bad_word in tokens for hate_words in x):
        good = False
        print ( sentence)
        count += 1
    if good:
        print(sentence)
        print('------------------------------------')
# Out:
# И как сейчас вам ваш майдан? органы на продажу пошли, лес и землю уже втихую продают. А скоро и законом можно будет иначе вмф кредит не даст.
# Скачите дальше майдауны))))﻿
# Нахрена ожног 30 ром ебашить﻿
# Россия 20:18﻿
# поздно стрелять боевыми начали,надо было стрелять как только все начиналось!﻿
# Надо было беркутовцам головы позерать к ебеням﻿
# Украина встала. Сегодня Армения встаёт. Мы уйдем от России.﻿
# 2:57 - ах как он горит! Аж душа радуется))﻿
# готовимся россия, у нас будет похлеще﻿
# Тупые хохлы , что вы несёте ?вы свергли легитимное правительство , путём военного переворота - потому-что хотели в Европу . Где ваша Европа ?туда вы едете работать шлюхами и рабами . У меня всё﻿
# жестяк﻿
# ...

# %%
count
# Out:
# 2531
