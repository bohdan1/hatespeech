# %%
import pandas as pd
from alphabet_detector import AlphabetDetector
import string
import re
import nltk
import numpy as np
import operator
from nltk.stem.snowball import SnowballStemmer
import xml.etree.ElementTree

# %%
path_to_data = '../data/comments1.csv'

# %%
df = pd.read_csv(path_to_data)
df = df.dropna()

# %%
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

# %%
def clean(x):
    ad = AlphabetDetector()
    res = x
    for ch in string.punctuation:                                                                                                     
        res = res.replace(ch, ' ')
    res = ''.join([i for i in res if not i.isdigit()])
    res = res.lower()
    res = emoji_pattern.sub(r' ', res)
    res = res.replace('\n', ' ')
    res = res.replace('\t', ' ')
    res = res.replace('\ufeff', ' ')
    res = res.replace('\r\n', '  ')
    res = res.replace('\xa0', ' ')
    res = res.replace('«', ' ')
    res = res.replace('»', ' ')
    res = res.replace('—', ' ')
    res = res.replace('ё', 'е')
    res = re.sub(' +',' ', res)
    if  not ad.only_alphabet_chars(res, "CYRILLIC"): 
        res = ''
    return res

# %%
df.text = df.text.apply(clean)
df = df[df.text != '']

# %%
manual_total = pd.read_csv('../data/manual.csv')

# Validation set
manual = manual_total.sample(1500)
testing_set = manual_total[~manual_total.id.isin(manual.id)]

df = df[~df.id.isin(manual_total.id)]

# %%
def stem(word):
    stemmer = SnowballStemmer("russian", ignore_stopwords=True) 
    stemmed_word = stemmer.stem(word)
    if len(stemmed_word) <= 2:
        return word
    return stemmed_word

# %%
def get_bad_words(path):
    path_to_bad_words = path 
    bad_words = open(path_to_bad_words).read().split('\n')[:-1]
    stemmed_dictionary = []
    for word in bad_words:
        stemmed_dictionary.append(stem(word))
    stemmed_dictionary = [i for i in stemmed_dictionary if len(i) > 2] 
    stemmed_dictionary.append('хуй') # nltk stemmer can not corectly stem word хуй
    stemmed_dictionary.append('хуе')
    stemmed_dictionary = list(set(stemmed_dictionary))
    return stemmed_dictionary

# %%
def get_unstem_bad_words(path):
    path_to_bad_words = path 
    bad_words = open(path_to_bad_words).read().split('\n')[:-1]
    stemmed_dictionary = []
    for word in bad_words:
        stemmed_dictionary.append(word)
    stemmed_dictionary.append('хуй')
    stemmed_dictionary = list(set(stemmed_dictionary))
    return stemmed_dictionary

# %%
def label(x):
    global stemmed_dictionary
    tokens = nltk.word_tokenize(x)
    for bad_word in stemmed_dictionary:
        for token in tokens:
            if bad_word in token:
                return True
    return False

# %%
def unstem_label(x):
    global stemmed_dictionary
    tokens = nltk.word_tokenize(x)
    for bad_word in stemmed_dictionary:
        for token in tokens:
            if bad_word == token:
                return True
    return False

# %%
all_words = dict()
for sentence in df.text:
    for token in nltk.word_tokenize(sentence):
        if token not in all_words:
            all_words[token] = token

# %%
all_stemmed = dict()
for sentence in df.text:
    for token in nltk.word_tokenize(sentence):
        if token not in all_stemmed:
            all_stemmed[token] = stem(token)

# %%
word_to_id = dict()
all_counts = dict()
for index, row in df.iterrows():
    tokens = nltk.word_tokenize(row.text)
    for token in tokens:
        word = stem(token)
        if word in word_to_id:
            word_to_id[word].append(row.video_id)
        else:
            word_to_id[word] = [row.video_id]
        if word in all_counts:
            all_counts[word] += 1
        else:
            all_counts[word] = 1
for key in word_to_id:
    word_to_id[key] = len(list(set(word_to_id[key])))

# %%
unstem_word_to_id = dict()
unstem_all_counts = dict()
for index, row in df.iterrows():
    tokens = nltk.word_tokenize(row.text)
    for token in tokens:
        word = token
        if word in unstem_word_to_id:
            unstem_word_to_id[word].append(row.video_id)
        else:
            unstem_word_to_id[word] = [row.video_id]
        if word in unstem_all_counts:
            unstem_all_counts[word] += 1
        else:
            unstem_all_counts[word] = 1
for key in unstem_word_to_id:
    unstem_word_to_id[key] = len(list(set(unstem_word_to_id[key])))

# %%
def likelihood(label, treshold):
    labeld_part = dict()
    part = df[df.label == label]
    for index, row in part.iterrows():
        sentence = row.text
        tokens = nltk.word_tokenize(sentence)
        for token in tokens:
            stemed = stem(token)
            if stemed != '':
                if word_to_id[stemed] > treshold:
                    if stemed in labeld_part:
                        labeld_part[stemed] += 1.0/len(part)
                    else:
                        labeld_part[stemed] = 1.0/len(part)
    return labeld_part

# %%
def unstem_likelihood(label, treshold):
    labeld_part = dict()
    part = df[df.label == label]
    for index, row in part.iterrows():
        sentence = row.text
        tokens = nltk.word_tokenize(sentence)
        for token in tokens:
            stemed = token
            if stemed != '':
                if unstem_word_to_id[stemed] > treshold:
                    if stemed  in labeld_part:
                        labeld_part[stemed] += 1.0/len(part)
                    else:
                        labeld_part[stemed] = 1.0/len(part)
    return labeld_part

# %%
def relative_distance(p_good, p_bad):
    difference = dict()
    for key in p_good:
        if key in p_bad:
            difference[key] =(p_bad[key] - p_good[key])/ np.maximum( p_bad[key], p_good[key]) 
    return difference

# %%
def log_odds(p_good, p_bad):
    ratio = dict()
    for key in p_good:
        if key in p_bad:
            odds_good =  p_good[key]/(1 -  p_good[key])
            odds_bad = p_bad[key]/(1- p_bad[key])
            ratio[key] = np.log(odds_bad/odds_good)
    return ratio

# %%
def sort(x, rev = True):
    return sorted(x.items(), key=operator.itemgetter(1), reverse=rev)

# %%
def update_dictionary(word):
    global stemmed_dictionary
    if len(word) <= 2:
        return False
    #for key in stemmed_dictionary:
        #if word in key:
            #return False
    stemmed_dictionary.append(word)
    return True

# %%
def evaluate(manual):
    manual['evaluation'] = manual.text.apply(label)
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for index, row in manual.iterrows():
        if row.label == True and row.evaluation == True:
            tp += 1
        if row.label == False and row.evaluation == False:
            tn += 1
        if row.label == False and row.evaluation == True:
            fp += 1
        if row.label == True and row.evaluation == False:
            #print(row.text)
            fn += 1
    accuracy = (tp + fp)/(tp + fp + fn + fp)
    precision = tp/(tp + fp)
    recall = tp/(tp + fn)
    f1  = 2 * (precision * recall)/(precision + recall)
    print('accuracy: ', accuracy)
    print('precision: ', precision)
    print('recall: ', recall)
    print('f1: ', f1)
    return f1

# %% [markdown]
# # Resultd for relative distance with unstemed words

# %%
stemmed_dictionary = get_unstem_bad_words('../data/bad_words.txt')
df['label'] = df.text.apply(unstem_label)
score0 = evaluate(manual)
treshold = 0.83
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = unstem_likelihood(True, amount_treshold)
    p_good = unstem_likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            stemmed_dictionary.append(key)
            new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.01
    df.label = df.text.apply(unstem_label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 0.83
# length of dict before  622
# length of dict after  630
# new words  ['сосать', 'очко', 'рот', 'ебаные', 'пошел', 'тупое', 'хули', 'иди']
# accuracy:  0.555858310626703
# precision:  0.6985294117647058
# recall:  0.5840163934426229
# f1:  0.6361607142857143
# f1  0.6411238825031927 treshold  0.83 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.5714285714285714
# precision:  0.7734375
# recall:  0.5963855421686747
# f1:  0.6734693877551021
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.6734693877551021

# %% [markdown]
# # Results for relative distance unstem small dictionary

# %%
stemmed_dictionary = get_unstem_bad_words('../data/bad_words_seed.txt')
df['label'] = df.text.apply(unstem_label)
score0 = evaluate(manual)
treshold = 0.83
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = unstem_likelihood(True, amount_treshold)
    p_good = unstem_likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            stemmed_dictionary.append(key)
            new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.01
    df.label = df.text.apply(unstem_label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 0.83
# length of dict before  5
# length of dict after  29
# new words  ['гореть', 'сосать', 'рот', 'тупая', 'бараны', 'похуй', 'нихуя', 'блядь', 'долбоеб', 'иди', 'пиздец', 'пидарасы', 'ебаные', 'блять', 'долбоебы', 'хуйня', 'бандеры', 'тварь', 'хули', 'соси', 'пизды', 'пидор', 'хуя', 'нахуй']
# accuracy:  0.3815789473684211
# precision:  0.6245210727969349
# recall:  0.33401639344262296
# f1:  0.4352469959946596
# ----------------------------------
# treshold 0.83
# length of dict before  29
# length of dict after  31
# new words  ['аду', 'пошел']
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.83
# length of dict before  31
# length of dict after  31
# new words  []
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.82
# length of dict before  31
# length of dict after  32
# new words  ['идите']
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.82
# length of dict before  32
# length of dict after  33
# new words  ['хуйню']
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.82
# length of dict before  33
# length of dict after  33
# new words  []
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.8099999999999999
# length of dict before  33
# length of dict after  33
# new words  []
# accuracy:  0.4005602240896359
# precision:  0.6048951048951049
# recall:  0.35450819672131145
# f1:  0.4470284237726098
# ----------------------------------
# treshold 0.7999999999999999
# length of dict before  33
# length of dict after  34
# new words  ['нахер']
# accuracy:  0.40083798882681565
# precision:  0.6027874564459931
# recall:  0.35450819672131145
# f1:  0.4464516129032258
# f1  0.4470284237726098 treshold  0.7999999999999999 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.38392857142857145
# precision:  0.6627906976744186
# recall:  0.3433734939759036
# f1:  0.45238095238095244
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.45238095238095244

# %% [markdown]
# # Results for log odds unstem

# %%
stemmed_dictionary = get_unstem_bad_words('../data/bad_words.txt')
df['label'] = df.text.apply(unstem_label)
score0 = evaluate(manual)
treshold = 2
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = unstem_likelihood(True, amount_treshold)
    p_good = unstem_likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            stemmed_dictionary.append(key)
            new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.1
    df.label = df.text.apply(unstem_label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 2
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.9
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.7999999999999998
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.6999999999999997
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.5999999999999996
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.4999999999999996
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.3999999999999995
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.2999999999999994
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.1999999999999993
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 1.0999999999999992
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 0.9999999999999992
# length of dict before  622
# length of dict after  622
# new words  []
# accuracy:  0.5121527777777778
# precision:  0.8508474576271187
# recall:  0.514344262295082
# f1:  0.6411238825031927
# ----------------------------------
# treshold 0.8999999999999992
# length of dict before  622
# length of dict after  623
# new words  ['тупое']
# accuracy:  0.5121107266435986
# precision:  0.847972972972973
# recall:  0.514344262295082
# f1:  0.6403061224489797
# f1  0.6411238825031927 treshold  0.8999999999999992 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.5105263157894737
# precision:  0.8762886597938144
# recall:  0.5120481927710844
# f1:  0.6463878326996197
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.6463878326996197

# %% [markdown]
# # Results for log odds unstem small dictionary

# %%
stemmed_dictionary = get_unstem_bad_words('../data/bad_words_seed.txt')
df['label'] = df.text.apply(unstem_label)
score0 = evaluate(manual)
treshold = 2
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = unstem_likelihood(True, amount_treshold)
    p_good = unstem_likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            stemmed_dictionary.append(key)
            new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.1
    df.label = df.text.apply(unstem_label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 2
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.9
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.7999999999999998
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.6999999999999997
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.5999999999999996
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.4999999999999996
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.3999999999999995
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.2999999999999994
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.1999999999999993
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 1.0999999999999992
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 0.9999999999999992
# length of dict before  5
# length of dict after  5
# new words  []
# accuracy:  0.16085271317829458
# precision:  0.8313253012048193
# recall:  0.1413934426229508
# f1:  0.24168126094570927
# ----------------------------------
# treshold 0.8999999999999992
# length of dict before  5
# length of dict after  11
# new words  ['сосать', 'нихуя', 'блядь', 'ебаные', 'соси', 'хуя']
# accuracy:  0.19186046511627908
# precision:  0.8585858585858586
# recall:  0.17418032786885246
# f1:  0.2896081771720613
# ----------------------------------
# treshold 0.8999999999999992
# length of dict before  11
# length of dict after  11
# new words  []
# accuracy:  0.19186046511627908
# precision:  0.8585858585858586
# recall:  0.17418032786885246
# f1:  0.2896081771720613
# ----------------------------------
# treshold 0.7999999999999993
# length of dict before  11
# length of dict after  38
# new words  ['аду', 'рот', 'тупая', 'бараны', 'бандеры', 'похуй', 'нахер', 'долбоеб', 'блять', 'пиздец', 'тварь', 'какого', 'пизды', 'нахуй', 'тупое', 'суки', 'твари', 'гореть', 'хули', 'идите', 'иди', 'короче', 'долбоебы', 'мрази', 'хуйня', 'пидарасы', 'пидор']
# accuracy:  0.4212707182320442
# precision:  0.6131147540983607
# recall:  0.3831967213114754
# f1:  0.4716267339218159
# ----------------------------------
# treshold 0.7999999999999993
# length of dict before  38
# length of dict after  43
# new words  ['пошел', 'тупые', 'ублюдки', 'хуйню', 'продажные']
# accuracy:  0.43342391304347827
# precision:  0.6112852664576802
# recall:  0.39959016393442626
# f1:  0.48327137546468407
# ----------------------------------
# treshold 0.7999999999999993
# length of dict before  43
# length of dict after  43
# new words  []
# accuracy:  0.43342391304347827
# precision:  0.6112852664576802
# recall:  0.39959016393442626
# f1:  0.48327137546468407
# ----------------------------------
# treshold 0.6999999999999993
# length of dict before  43
# length of dict after  71
# new words  ['очко', 'пишешь', 'хохлы', 'хохол', 'никому', 'площади', 'мясо', 'хер', 'вали', 'жопу', 'домой', 'говоря', 'твой', 'земли', 'бабло', 'убили', 'шли', 'рабов', 'бендеровцы', 'бандерлоги', 'бендеры', 'какую', 'мать', 'начали', 'мусора', 'пидоры', 'бандера', 'скот']
# accuracy:  0.4888641425389755
# precision:  0.5330296127562643
# recall:  0.47950819672131145
# f1:  0.5048543689320389
# ----------------------------------
# treshold 0.6999999999999993
# length of dict before  71
# length of dict after  138
# new words  ['общем', 'подумайте', 'мол', 'дальше', 'своими', 'западная', 'руси', 'давать', 'около', 'работать', 'европейцы', 'флагами', 'сидят', 'предатели', 'тупо', 'убивают', 'родины', 'дом', 'кусок', 'героев', 'кацапы', 'зарплаты', 'хочешь', 'город', 'которого', 'моего', 'твое', 'воевать', 'дали', 'смерти', 'получили', 'тд', 'тысячи', 'вашей', 'дома', 'твою', 'идею', 'рады', 'думаешь', 'сюда', 'посмотрим', 'обратно', 'газа', 'землю', 'лидеры', 'нибудь', 'месяц', 'вон', 'работы', 'нах', 'давали', 'будете', 'нужны', 'нужна', 'западу', 'хрен', '–', 'хохлов', 'думаете', 'кричать', 'понимаете', 'герой', 'куча', 'терпеть', 'сс', 'повод', 'детям']
# accuracy:  0.5584518167456556
# precision:  0.4497878359264498
# recall:  0.6516393442622951
# f1:  0.5322175732217573
# ----------------------------------
# treshold 0.6999999999999993
# length of dict before  138
# length of dict after  578
# new words  ['стать', 'говорите', 'президентом', 'кричат', 'крови', 'скажу', 'и', 'студенты', 'имеют', 'вам', 'иметь', 'миллионов', 'год', 'украинским', 'виде', 'другое', 'живут', 'могли', 'что', 'одессе', 'они', 'туда', 'действий', 'них', 'при', 'проще', 'мировой', 'большинство', 'города', 'можем', 'видели', 'этими', 'своего', 'своих', 'лишь', 'каждый', 'первых', 'дела', 'других', 'свое', 'выйти', 'платить', 'после', 'возможность', 'хоть', 'предателей', 'земле', 'готовы', 'этом', 'историю', 'дадут', 'места', 'была', 'твои', 'пока', 'момент', 'новый', 'бесплатно', 'который', 'придется', 'границы', 'вашего', 'крыму', 'пришли', 'наших', 'человеком', 'одной', 'нем', 'когда', 'сценарий', 'территории', 'войну', 'жителей', 'ради', 'страну', 'нашей', 'разных', 'сами', 'пару', 'русскими', 'жили', 'одном', 'выборов', 'своим', 'самой', 'спокойно', 'силы', 'никогда', 'тимошенко', 'хотите', 'назад', 'даже', 'янык', 'хочет', 'уверен', 'вполне', 'выбор', 'глазами', 'всю', 'интересы', 'именно', 'идут', 'наше', 'посмотрел', 'называют', 'чтоб', 'ющенко', 'со', 'граждан', 'плохо', 'факт', 'лично', 'донбассе', 'видите', 'гражданской', 'мирных', 'проблем', 'можешь', 'вы', 'сделать', 'эти', 'государство', 'лет', 'буду', 'пол', 'ваши', 'помощь', 'жить', 'видишь', 'ваших', 'воров', 'сразу', 'имя', 'этим', 'среди', 'того', 'киеве', 'цель', 'ситуацию', 'мира', 'чтобы', 'году', 'нормальные', 'своем', 'начал', 'едут', 'ваша', 'остальные', 'над', 'же', 'рабами', 'ес', 'нужен', 'друга', 'стран', 'дать', 'помочь', 'получить', 'львов', 'области', 'д', 'лезть', 'кому', 'вас', 'америке', 'страны', 'опять', 'кстати', 'юго', 'вдруг', 'тот', 'потом', 'говорят', 'можете', 'каким', 'самые', 'последние', 'наши', 'придут', 'ни', 'пускай', 'стояли', 'семьи', 'ждут', 'армии', 'деньги', 'были', 'куда', 'хотят', 'запад', 'россией', 'интернете', 'вашу', 'родители', 'ответить', 'земля', 'жизнь', 'строить', 'которые', 'виноваты', 'миру', 'благодаря', 'хотели', 'население', 'всего', 'власть', 'живете', 'итоге', 'головы', 'руками', 'делали', 'закончится', 'европа', 'будут', 'собой', 'наконец', 'рф', 'митинг', 'граждане', 'устроили', 'рабство', 'брать', 'скажите', 'переворот', 'которое', 'время', 'месте', 'свои', 'сейчас', 'славяне', 'дает', 'хватит', 'крым', 'всей', 'нато', 'нормально', 'например', 'яныка', 'говоришь', 'украинские', 'экономики', 'новые', 'к', 'оппозиция', 'референдум', 'войне', 'европой', 'думают', 'хотя', 'бандеровцы', 'друг', 'свой', 'какие', 'плохого', 'поможет', 'понимают', 'этому', 'русским', 'стоят', 'одни', 'государства', 'нормальный', 'жители', 'во', 'европе', 'другие', 'нам', 'взять', 'иначе', 'равно', 'цены', 'никто', 'европу', 'солдат', 'честно', 'быстро', 'работу', 'европы', 'приказ', 'сил', 'минимум', 'типа', 'делать', 'быдлом', 'хватает', 'годы', 'населения', 'гос', 'пойдет', 'истории', 'случае', 'также', 'ходить', 'украинский', 'демократии', 'своей', 'евро', 'дал', 'ваш', 'кровью', 'снова', 'вашим', 'придет', 'востока', 'если', 'путем', 'детей', 'войска', 'нашего', 'прежде', 'счет', 'г', 'якобы', 'западе', 'воевали', 'вокруг', 'стал', 'русских', 'сегодня', 'т', 'идти', 'будто', 'уровень', 'решил', 'странах', 'работа', 'знаете', 'часть', 'щас', 'говорили', 'был', 'нацистов', 'решать', 'сидеть', 'сотни', 'подобные', 'улицы', 'никаких', 'простой', 'мы', 'пришел', 'стали', 'пошли', 'ладно', 'большая', 'новых', 'кличко', 'мало', 'хотим', 'те', 'которым', 'будущее', 'их', 'киев', 'братьев', 'армия', 'везде', 'теперь', 'дети', 'денег', 'востоке', 'получилось', 'поводу', 'ничего', 'ведь', 'работают', 'восток', 'войны', 'им', 'остались', 'том', 'российские', 'газ', 'проблемы', 'этого', 'последний', 'тогда', 'могут', 'тысяч', 'приехали', 'стране', 'вышли', 'нас', 'евросоюз', 'евросоюзе', 'будем', 'руку', 'ней', 'либо', 'рядом', 'говна', 'ним', 'германии', 'будет', 'ссср', 'убивать', 'даст', 'всему', 'достаточно', 'интернет', 'многих', 'насрать', 'сможет', 'жрать', 'запада', 'россию', 'посмотрите', 'всеми', 'выгодно', 'искренне', 'которая', 'знаешь', 'кор ...
# accuracy:  0.597983870967742
# precision:  0.32838840188806473
# recall:  0.9979508196721312
# f1:  0.49416539827498734
# f1  0.5322175732217573 treshold  0.6999999999999993 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.6007281553398058
# precision:  0.33535353535353535
# recall:  1.0
# f1:  0.5022692889561271
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.5022692889561271

# %% [markdown]
# # Results for relative distance

# %%
stemmed_dictionary = get_bad_words('../data/bad_words.txt')
df['label'] = df.text.apply(label)
score0 = evaluate(manual)
treshold = 0.83
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = likelihood(True, amount_treshold)
    p_good = likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            if update_dictionary(key):
                new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.01
    df.label = df.text.apply(label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.5877437325905293
# precision:  0.7274881516587678
# recall:  0.6290983606557377
# f1:  0.6747252747252747
# ----------------------------------
# treshold 0.83
# length of dict before  476
# length of dict after  482
# new words  ['треб', 'бендеровск', 'вонюч', 'кацапск', 'тип', 'западенск']
# accuracy:  0.5967302452316077
# precision:  0.7191780821917808
# recall:  0.6454918032786885
# f1:  0.6803455723542117
# ----------------------------------
# treshold 0.83
# length of dict before  482
# length of dict after  483
# new words  ['пошел']
# accuracy:  0.5967302452316077
# precision:  0.7191780821917808
# recall:  0.6454918032786885
# f1:  0.6803455723542117
# ----------------------------------
# treshold 0.83
# length of dict before  483
# length of dict after  483
# new words  []
# accuracy:  0.5967302452316077
# precision:  0.7191780821917808
# recall:  0.6454918032786885
# f1:  0.6803455723542117
# ----------------------------------
# treshold 0.82
# length of dict before  483
# length of dict after  483
# new words  []
# accuracy:  0.5967302452316077
# precision:  0.7191780821917808
# recall:  0.6454918032786885
# f1:  0.6803455723542117
# ----------------------------------
# treshold 0.8099999999999999
# length of dict before  483
# length of dict after  486
# new words  ['рот', 'жрат', 'член']
# accuracy:  0.5946601941747572
# precision:  0.6571428571428571
# recall:  0.6598360655737705
# f1:  0.6584867075664621
# f1  0.6803455723542117 treshold  0.8099999999999999 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.6060606060606061
# precision:  0.69375
# recall:  0.6686746987951807
# f1:  0.6809815950920245
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.6809815950920245

# %% [markdown]
# # Results for relative distance with small seed

# %%
stemmed_dictionary = get_bad_words('../data/bad_words_seed.txt')
df['label'] = df.text.apply(label)
score0 = evaluate(manual)
treshold = 0.90
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = likelihood(True, amount_treshold)
    p_good = likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            if update_dictionary(key):
                new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        #result.append([score0, treshold, amount_treshold])
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.01
    df.label = df.text.apply(label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.2737642585551331
# precision:  0.8680555555555556
# recall:  0.25614754098360654
# f1:  0.39556962025316456
# ----------------------------------
# treshold 0.9
# length of dict before  6
# length of dict after  12
# new words  ['треб', 'пох', 'сос', 'ебуч', 'нах', 'ниху']
# accuracy:  0.3741935483870968
# precision:  0.7155172413793104
# recall:  0.3401639344262295
# f1:  0.46111111111111114
# ----------------------------------
# treshold 0.9
# length of dict before  12
# length of dict after  12
# new words  []
# accuracy:  0.3741935483870968
# precision:  0.7155172413793104
# recall:  0.3401639344262295
# f1:  0.46111111111111114
# ----------------------------------
# treshold 0.89
# length of dict before  12
# length of dict after  13
# new words  ['хуя']
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 0.89
# length of dict before  13
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 0.88
# length of dict before  13
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 0.87
# length of dict before  13
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 0.86
# length of dict before  13
# length of dict after  14
# new words  ['хлеб']
# accuracy:  0.3814102564102564
# precision:  0.7142857142857143
# recall:  0.3483606557377049
# f1:  0.46831955922865015
# ----------------------------------
# treshold 0.86
# length of dict before  14
# length of dict after  14
# new words  []
# accuracy:  0.3814102564102564
# precision:  0.7142857142857143
# recall:  0.3483606557377049
# f1:  0.46831955922865015
# ----------------------------------
# treshold 0.85
# length of dict before  14
# length of dict after  15
# new words  ['промышлен']
# accuracy:  0.38338658146964855
# precision:  0.7125
# recall:  0.35040983606557374
# f1:  0.4697802197802198
# ----------------------------------
# treshold 0.85
# length of dict before  15
# length of dict after  15
# new words  []
# accuracy:  0.38338658146964855
# precision:  0.7125
# recall:  0.35040983606557374
# f1:  0.4697802197802198
# ----------------------------------
# treshold 0.84
# length of dict before  15
# length of dict after  16
# new words  ['уебк']
# accuracy:  0.38498402555910544
# precision:  0.7136929460580913
# recall:  0.3524590163934426
# f1:  0.47187928669410156
# ----------------------------------
# treshold 0.84
# length of dict before  16
# length of dict after  16
# new words  []
# accuracy:  0.38498402555910544
# precision:  0.7136929460580913
# recall:  0.3524590163934426
# f1:  0.47187928669410156
# ----------------------------------
# treshold 0.83
# length of dict before  16
# length of dict after  18
# new words  ['хул', 'пидорас']
# accuracy:  0.3961661341853035
# precision:  0.7217741935483871
# recall:  0.3668032786885246
# f1:  0.48641304347826086
# ----------------------------------
# treshold 0.83
# length of dict before  18
# length of dict after  18
# new words  []
# accuracy:  0.3961661341853035
# precision:  0.7217741935483871
# recall:  0.3668032786885246
# f1:  0.48641304347826086
# ----------------------------------
# treshold 0.82
# length of dict before  18
# length of dict after  18
# new words  []
# accuracy:  0.3961661341853035
# precision:  0.7217741935483871
# recall:  0.3668032786885246
# f1:  0.48641304347826086
# ----------------------------------
# treshold 0.8099999999999999
# length of dict before  18
# length of dict after  20
# new words  ['пидарас', 'млн']
# accuracy:  0.3984126984126984
# precision:  0.7171314741035857
# recall:  0.36885245901639346
# f1:  0.4871447902571042
# ----------------------------------
# treshold 0.8099999999999999
# length of dict before  20
# length of dict after  20
# new words  []
# accuracy:  0.3984126984126984
# precision:  0.7171314741035857
# recall:  0.36885245901639346
# f1:  0.4871447902571042
# ----------------------------------
# treshold 0.7999999999999999
# length of dict before  20
# length of dict after  23
# new words  ['срок', 'бизнес', 'пошел']
# accuracy:  0.3987341772151899
# precision:  0.7142857142857143
# recall:  0.36885245901639346
# f1:  0.4864864864864865
# f1  0.4871447902571042 treshold  0.7999999999999999 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.4
# precision:  0.6931818181818182
# recall:  0.3674698795180723
# f1:  0.4803149606299213
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.4803149606299213

# %% [markdown]
# # Results for log odds

# %%
stemmed_dictionary = get_bad_words('../data/bad_words.txt')
df['label'] = df.text.apply(label)
score0 = evaluate(manual)
treshold = 2
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = likelihood(True, amount_treshold)
    p_good = likelihood(False, amount_treshold)
    prob = log_odds(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            if update_dictionary(key):
                new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.1
    df.label = df.text.apply(label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.5877437325905293
# precision:  0.7274881516587678
# recall:  0.6290983606557377
# f1:  0.6747252747252747
# ----------------------------------
# treshold 2
# length of dict before  476
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# length of dict after  479
# new words  ['треб', 'тип', 'западенск']
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 2
# length of dict before  479
# length of dict after  479
# new words  []
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 1.9
# length of dict before  479
# length of dict after  479
# new words  []
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 1.7999999999999998
# length of dict before  479
# length of dict after  481
# new words  ['пошел', 'вонюч']
# accuracy:  0.5953678474114441
# precision:  0.7185354691075515
# recall:  0.6434426229508197
# f1:  0.6789189189189189
# ----------------------------------
# treshold 1.7999999999999998
# length of dict before  481
# length of dict after  481
# new words  []
# accuracy:  0.5953678474114441
# precision:  0.7185354691075515
# recall:  0.6434426229508197
# f1:  0.6789189189189189
# ----------------------------------
# treshold 1.6999999999999997
# length of dict before  481
# length of dict after  484
# new words  ['бендеровск', 'кацапск', 'член']
# accuracy:  0.5975609756097561
# precision:  0.7165532879818595
# recall:  0.6475409836065574
# f1:  0.6803013993541444
# ----------------------------------
# treshold 1.6999999999999997
# length of dict before  484
# length of dict after  484
# new words  []
# accuracy:  0.5975609756097561
# precision:  0.7165532879818595
# recall:  0.6475409836065574
# f1:  0.6803013993541444
# ----------------------------------
# treshold 1.5999999999999996
# length of dict before  484
# length of dict after  489
# new words  ['рот', 'жрат', 'хлеб', 'принцип', 'что']
# accuracy:  0.5911413969335605
# precision:  0.5057636887608069
# recall:  0.7192622950819673
# f1:  0.5939086294416244
# f1  0.6803013993541444 treshold  1.5999999999999996 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.6044776119402985
# precision:  0.51440329218107
# recall:  0.7530120481927711
# f1:  0.6112469437652812
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.6112469437652812

# %% [markdown]
# # Resulst for log odds small dicitonary

# %%
stemmed_dictionary = get_bad_words('../data/bad_words_seed.txt')
df['label'] = df.text.apply(label)
score0 = evaluate(manual)
treshold = 2.3
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = likelihood(True, amount_treshold)
    p_good = likelihood(False, amount_treshold)
    prob = log_odds(p_good, p_bad)
    print(sort(prob)[:15])
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            if update_dictionary(key):
                new_words.append(key)

    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.1
    df.label = df.text.apply(label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.2737642585551331
# precision:  0.8680555555555556
# recall:  0.25614754098360654
# f1:  0.39556962025316456
# ----------------------------------
# treshold 2.3
# length of dict before  6
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# [('не', 4.106855420729722), ('нах', 3.70784457636469), ('треб', 3.130972245837058), ('пох', 2.9925091867538334), ('сос', 2.4087789763755096), ('хул', 2.159901165863682), ('в', 1.9640348340170493), ('пидарас', 1.9164883759960185), ('хлеб', 1.8709229875901296), ('долбоеб', 1.802569045002336), ('тупорыл', 1.7142458478129305), ('соса', 1.6861210937834334), ('рот', 1.6814384484165137), ('гроші', 1.6407596685814936), ('кацапск', 1.6182518828381507)]
# length of dict after  12
# new words  ['треб', 'пох', 'сос', 'ебуч', 'нах', 'ниху']
# accuracy:  0.3741935483870968
# precision:  0.7155172413793104
# recall:  0.3401639344262295
# f1:  0.46111111111111114
# ----------------------------------
# treshold 2.3
# length of dict before  12
# [('на', 2.054430564474757), ('хул', 1.8528522566965775), ('срок', 1.7144092241872495), ('пидарас', 1.671217573299505), ('квартир', 1.55185159957179), ('бизнес', 1.5194129050159764), ('самі', 1.4971307408278682), ('здан', 1.47539930871282), ('долбоеб', 1.452820729001537), ('связ', 1.4525768831451396), ('бюджет', 1.439122094106573), ('мол', 1.4311911391193117), ('едут', 1.4160650951202018), ('рот', 1.4159026618292079), ('хохол', 1.4134436385099605)]
# length of dict after  12
# new words  []
# accuracy:  0.3741935483870968
# precision:  0.7155172413793104
# recall:  0.3401639344262295
# f1:  0.46111111111111114
# ----------------------------------
# treshold 2.1999999999999997
# length of dict before  12
# [('на', 2.054430564474757), ('хул', 1.8528522566965775), ('срок', 1.7144092241872495), ('пидарас', 1.671217573299505), ('квартир', 1.55185159957179), ('бизнес', 1.5194129050159764), ('самі', 1.4971307408278682), ('здан', 1.47539930871282), ('долбоеб', 1.452820729001537), ('связ', 1.4525768831451396), ('бюджет', 1.439122094106573), ('мол', 1.4311911391193117), ('едут', 1.4160650951202018), ('рот', 1.4159026618292079), ('хохол', 1.4134436385099605)]
# length of dict after  13
# new words  ['хуя']
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 2.1999999999999997
# length of dict before  13
# [('на', 2.0265254681484084), ('хул', 1.839569464005381), ('срок', 1.7011501240825206), ('пидарас', 1.678337554964546), ('квартир', 1.538590460095769), ('бизнес', 1.5061153616118514), ('самі', 1.4838712048640805), ('здан', 1.4621328107726088), ('долбоеб', 1.4394652289670746), ('связ', 1.4393051312409069), ('бюджет', 1.4258433662886476), ('мол', 1.4178583224071037), ('едут', 1.4028174784030993), ('рот', 1.4025627443070496), ('хохол', 1.400176977021904)]
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 2.0999999999999996
# length of dict before  13
# [('на', 2.0265254681484084), ('хул', 1.839569464005381), ('срок', 1.7011501240825206), ('пидарас', 1.678337554964546), ('квартир', 1.538590460095769), ('бизнес', 1.5061153616118514), ('самі', 1.4838712048640805), ('здан', 1.4621328107726088), ('долбоеб', 1.4394652289670746), ('связ', 1.4393051312409069), ('бюджет', 1.4258433662886476), ('мол', 1.4178583224071037), ('едут', 1.4028174784030993), ('рот', 1.4025627443070496), ('хохол', 1.400176977021904)]
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 1.9999999999999996
# length of dict before  13
# [('на', 2.0265254681484084), ('хул', 1.839569464005381), ('срок', 1.7011501240825206), ('пидарас', 1.678337554964546), ('квартир', 1.538590460095769), ('бизнес', 1.5061153616118514), ('самі', 1.4838712048640805), ('здан', 1.4621328107726088), ('долбоеб', 1.4394652289670746), ('связ', 1.4393051312409069), ('бюджет', 1.4258433662886476), ('мол', 1.4178583224071037), ('едут', 1.4028174784030993), ('рот', 1.4025627443070496), ('хохол', 1.400176977021904)]
# length of dict after  13
# new words  []
# accuracy:  0.3790322580645161
# precision:  0.7191489361702128
# recall:  0.3463114754098361
# f1:  0.46749654218533887
# ----------------------------------
# treshold 1.8999999999999995
# length of dict before  13
# [('на', 2.0265254681484084), ('хул', 1.839569464005381), ('срок', 1.7011501240825206), ('пидарас', 1.678337554964546), ('квартир', 1.538590460095769), ('бизнес', 1.5061153616118514), ('самі', 1.4838712048640805), ('здан', 1.4621328107726088), ('долбоеб', 1.4394652289670746), ('связ', 1.4393051312409069), ('бюджет', 1.4258433662886476), ('мол', 1.4178583224071037), ('едут', 1.4028174784030993), ('рот', 1.4025627443070496), ('хохол', 1.400176977021904)]
# length of dict after  15
# new words  ['хлеб', 'промышлен']
# accuracy:  0.38338658146964855
# precision:  0.7125
# recall:  0.35040983606557374
# f1:  0.4697802197802198
# ----------------------------------
# treshold 1.8999999999999995
# length of dict before  15
# [('на', 2.086650198741112), ('хул', 1.8179845385841982), ('бизнес', 1.6828961348427636), ('срок', 1.6796030606741463), ('пидарас', 1.6566134098988763), ('квартир', 1.5170401181222508), ('средн', 1.4918542080220554), ('бюджет', 1.4841507086959318), ('самі', 1.4623234207073657), ('связ', 1.4620197776948454), ('идут', 1.4563881708610065), ('здан', 1.4405738895150313), ('долбоеб', 1.4379695371224255), ('результат', 1.4353579687007616), ('долг', 1.4294372692884862)]
# length of dict after  15
# new words  []
# accuracy:  0.38338658146964855
# precision:  0.7125
# recall:  0.35040983606557374
# f1:  0.4697802197802198
# ----------------------------------
# treshold 1.7999999999999994
# length of dict before  15
# [('на', 2.086650198741112), ('хул', 1.8179845385841982), ('бизнес', 1.6828961348427636), ('срок', 1.6796030606741463), ('пидарас', 1.6566134098988763), ('квартир', 1.5170401181222508), ('средн', 1.4918542080220554), ('бюджет', 1.4841507086959318), ('самі', 1.4623234207073657), ('связ', 1.4620197776948454), ('идут', 1.4563881708610065), ('здан', 1.4405738895150313), ('долбоеб', 1.4379695371224255), ('результат', 1.4353579687007616), ('долг', 1.4294372692884862)]
# length of dict after  19
# new words  ['хул', 'что', 'уебк', 'пидорас']
# accuracy:  0.5103189493433395
# precision:  0.46875
# recall:  0.5225409836065574
# f1:  0.49418604651162795
# ----------------------------------
# treshold 1.7999999999999994
# length of dict before  19
# [('происход', 2.90641631696967), ('увер', 2.5243663941842205), ('на', 2.2790328669856867), ('того', 2.265439528577167), ('бизнес', 2.244073118994181), ('средн', 2.2009627566066112), ('экономик', 2.1434476947267336), ('обща', 2.080423700112315), ('контрол', 2.069989605126113), ('квартир', 2.0676176117892644), ('границ', 2.0538731834172994), ('связ', 2.026787051284445), ('большинств', 2.001968195293667), ('открыт', 1.9878934566570725), ('приход', 1.9699633308979412)]
# length of dict after  151
# new words  ['так', 'развит', 'обща', 'большинств', 'хот', 'образ', 'управля', 'арм', 'оранжев', 'родител', 'подума', 'того', 'обратн', 'достаточн', 'факт', 'происход', 'увер', 'вполн', 'контрол', 'специальн', 'открыт', 'вспомн', 'границ', 'понятн', 'средн', 'квартир', 'экономик', 'нек', 'бюджет', 'миров', 'знает', 'ситуац', 'способн', 'приход', 'баррикад', 'котор', 'использ', 'бизнес', 'сейчас', 'нынешн', 'выгодн', 'связ', 'это', 'сомнева', 'положен', 'смогл', 'вокруг', 'знал', 'здан', 'устраива', 'переворот', 'развива', 'случа', 'независим', 'продава', 'представля', 'сдела', 'помощ', 'том', 'республик', 'преврат', 'активист', 'созда', 'насчет', 'курс', 'помн', 'коррупц', 'завод', 'станов', 'производств', 'имеют', 'они', 'интерес', 'забра', 'крич', 'услов', 'ассоциац', 'евросоюз', 'обидн', 'масс', 'говор', 'воен', 'как', 'вступлен', 'выйт', 'дума', 'доказа', 'лозунг', 'невозможн', 'участ', 'допуст', 'измен', 'чечн', 'были', 'конфликт', 'толк', 'куч', 'член', 'например', 'нибудь', 'кита', 'призна', 'постоя', 'личн', 'захват', 'организац', 'пойдет', 'прежд', 'ресурс', 'забыва', 'продукт', 'дела', 'понима', 'фраз', 'произошл', 'имет', 'спрос', 'благ', 'товар', 'экономическ', 'необходим', 'сложн', 'волн', 'общ', 'счита', 'ленин', 'сел', 'скажут', 'твор', 'повод', 'потому', 'соглашен']
# accuracy:  0.5722477064220184
# precision:  0.37074148296593185
# recall:  0.7581967213114754
# f1:  0.4979811574697174
# ----------------------------------
# treshold 1.7999999999999994
# length of dict before  151
# [('будто', 4.003121454294141), ('покупа', 3.8974099629202312), ('хаос', 3.87486692670461), ('в', 3.859921281232788), ('результат', 3.782022251679524), ('попытк', 3.7538881109584255), ('беспорядк', 3.6453939525429853), ('вест', 3.5095336165353794), ('поступа', 3.507457023238202), ('привел', 3.3964038570755077), ('систем', 3.3182825143350727), ('вывод', 3.1959900024359653), ('отношен', 3.1658476042156067), ('обрат', 3.112202850036321), ('таможен', 3.110827570985875)]
# length of dict after  742
# new words  ['миллион', 'сказк', 'другой', 'погибл', 'привел', 'известн', 'регион', 'видет', 'очевидн', 'поня', 'сценар', 'реш', 'срок', 'сем', 'приня', 'быстр', 'продолжа', 'живут', 'мол', 'национальн', 'тяжел', 'перв', 'довольн', 'при', 'если', 'российск', 'дел', 'собствен', 'долг', 'моей', 'насра', 'слыша', 'кстат', 'мне', 'мечта', 'ора', 'правительств', 'событ', 'город', 'предприят', 'демократическ', 'виж', 'поступа', 'ничего', 'европ', 'рассказыва', 'оно', 'его', 'умира', 'станет', 'знат', 'стат', 'хаос', 'настроен', 'мирн', 'парт', 'для', 'таможен', 'акц', 'кремл', 'закон', 'свал', 'идут', 'внутрен', 'истор', 'войск', 'никогда', 'хочет', 'гряз', 'цивилизова', 'нуж', 'молодеж', 'выбор', 'виноват', 'украинск', 'ющенк', 'равн', 'нужн', 'братск', 'печальн', 'поймет', 'вступа', 'меша', 'мер', 'знаеш', 'богат', 'прост', 'внук', 'эти', 'лет', 'хер', 'дешев', 'пережива', 'все', 'стран', 'было', 'сегодн', 'идет', 'чиновник', 'уда', 'переста', 'насил', 'власт', 'более', 'неужел', 'баз', 'разве', 'территор', 'них', 'едут', 'везд', 'либ', 'выступа', 'особен', 'знаком', 'пост', 'старик', 'штурм', 'пишет', 'евроинтеграц', 'ник', 'плат', 'результат', 'одн', 'корн', 'вышл', 'сможет', 'остальн', 'след', 'вдруг', 'неб', 'культурн', 'солдат', 'обрат', 'заработа', 'реша', 'горазд', 'кром', 'жил', 'евромайдан', 'якоб', 'ценност', 'грязн', 'важн', 'теря', 'красн', 'вниман', 'врод', 'вывод', 'инач', 'знают', 'митинг', 'взгляд', 'жертв', 'агресс', 'отношен', 'качеств', 'тем', 'зна', 'объясн', 'ним', 'язык', 'советск', 'покупа', 'всяк', 'отлич', 'двух', 'видел', 'основн', 'славянск', 'бес', 'пробл', 'боится', 'коктейл', 'рус', 'человек', 'друг', 'попытк', 'чего', 'сми', 'дом', 'уход', 'собира', 'сша', 'рабоч', 'бесплатн', 'вопрос', 'европейц', 'работ', 'вест', 'мяс', 'почти', 'езд', 'выход', 'гражда', 'систем', 'приказ', 'беспорядк', 'может', 'предлага', 'росс', 'гос', 'жизн', 'ход', 'могл', 'сраз', 'вод', 'попрос', 'девушк', 'част', 'вступ', 'отда', 'преда', 'оппозиц', 'русск', 'держа', 'родственник', 'быть', 'стал', 'будто', 'даст', 'деньг', 'работа', 'выбира', 'выбра', 'живет', 'боятся', 'устро', 'игр', 'жит', 'обязательн', 'прошл', 'всегда', 'ему', 'пойм', 'тех', 'отдельн', 'повтор', 'област', 'денег', 'обычн', 'нас', 'между', 'ибо', 'разн', 'спор', 'защит', 'журналист', 'много', 'могут', 'друз', 'борьб', 'покажет', 'пыта', 'сто', 'плева', 'памятник', 'прода', 'моего', 'имен', 'логик', 'короч', 'ссср', 'налог', 'спокойн', 'государствен', 'унитаз', 'подня', 'вонюч', 'неч', 'совершен', 'революц', 'поднима', 'знач', 'люд', 'услыша', 'принцип', 'боя', 'современ', 'воева', 'никт', 'милиц', 'увидел', 'конкретн', 'нормальн', 'оруж', 'нефт', 'пут', 'добива', 'форм', 'принима', 'стро', 'выполня', 'год', 'действительн', 'разбира', 'справедлив', 'поменя', 'нагл', 'последн', 'народ', 'лидер', 'вот', 'реч', 'союз', 'ведут', 'вариант', 'жестк', 'дет', 'геноцид', 'дне', 'смен', 'откр', 'явля', 'глав', 'шакал', 'правител', 'россия', 'кида', 'улиц', 'спрашива', 'дадут', 'была', 'потеря', 'назва', 'момент', 'борол', 'крайн', 'демократ', 'ваш', 'процент', 'включ', 'убра', 'гон', 'него', 'относ', 'пишут', 'сут', 'пят', 'гражданск', 'вер', 'толп', 'начина', 'расстрелива', 'центр', 'ответ', 'будущ', 'веша', 'желан', 'количеств', 'позиц', 'местн', 'историческ', 'даже', 'вор', 'понят', 'всего', 'площад', 'времен', 'зарплат', 'идею', 'прощ', 'способ', 'граждан', 'ненавист', 'получа', 'тип', 'палк', 'сво', 'хрен', 'проблем', 'терпет', 'поддержа', 'снов', 'нача', 'немц', 'уровен', 'решен', 'кем', 'взят', 'возможн', 'совет', 'автобус', 'провокац', 'окол', 'вернул', 'еще', 'чуж', 'ноч', 'боевик', 'труд', 'постро', 'дан', 'люб', 'мое', 'телевизор', 'оказа', 'проход', 'плох', 'нескольк', 'служб', 'сам', 'абсолютн', 'враг', 'бабк', 'представител', 'миллиард', 'судьб', 'когда', 'герман', 'интернет', 'нельзя', 'меня', 'сир', 'лишн', 'узна', 'далек', 'лив', 'показа', 'россиян', 'запад', 'числ', 'кровав', 'польз', 'зарабатыва', 'школ', 'появ', 'посмотрет', 'ведет', 'вид', 'поли ...
# accuracy:  0.5932802829354553
# precision:  0.3390461997019374
# recall:  0.9323770491803278
# f1:  0.4972677595628415
# f1  0.4979811574697174 treshold  1.7999999999999994 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.589572192513369
# precision:  0.3401360544217687
# recall:  0.9036144578313253
# f1:  0.49423393739703453
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.49423393739703453

# %% [markdown]
# # Result for mix of relative distance and log odds

# %%
stemmed_dictionary = get_bad_words('../data/bad_words.txt')
df['label'] = df.text.apply(label)
score0 = evaluate(manual)
treshold = 0.9
log_treshold = 2
amount_treshold = 30
while(True):
    print('----------------------------------')
    old_len = len(stemmed_dictionary)
    print('treshold', treshold)
    print('length of dict before ', old_len)
    p_bad = likelihood(True, amount_treshold)
    p_good = likelihood(False, amount_treshold)
    prob = relative_distance(p_good, p_bad)
    log_prob =log_odds(p_good, p_bad)
    new_words = []
    for key in prob:
        if prob[key] > treshold:
            if update_dictionary(key):
                new_words.append(key)
    for key in log_prob:
        if log_prob[key] > log_treshold:
            if update_dictionary(key):
                new_words.append(key)


    print('length of dict after ',len(stemmed_dictionary))
    print('new words ', new_words)
    score1 = evaluate(manual)
    if score1 < score0:
        print('f1 ', score0, 'treshold ', treshold, 'amount treshold ', amount_treshold)
        break
    else:
        score0 = score1

    if len(stemmed_dictionary) == old_len:
        treshold -= 0.01
        log_treshold -= 0.1
    df.label = df.text.apply(label)
print("-------------- TESTING SET RESULTS -----------")
evaluate(testing_set)
# Out:
# accuracy:  0.5877437325905293
# precision:  0.7274881516587678
# recall:  0.6290983606557377
# f1:  0.6747252747252747
# ----------------------------------
# treshold 0.9
# length of dict before  476
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# length of dict after  480
# new words  ['тип', 'треб', 'тип', 'западенск']
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 0.9
# length of dict before  480
# length of dict after  480
# new words  []
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 0.89
# length of dict before  480
# length of dict after  480
# new words  []
# accuracy:  0.5940054495912807
# precision:  0.7178899082568807
# recall:  0.6413934426229508
# f1:  0.6774891774891775
# ----------------------------------
# treshold 0.88
# length of dict before  480
# length of dict after  482
# new words  ['пошел', 'вонюч']
# accuracy:  0.5953678474114441
# precision:  0.7185354691075515
# recall:  0.6434426229508197
# f1:  0.6789189189189189
# ----------------------------------
# treshold 0.88
# length of dict before  482
# length of dict after  482
# new words  []
# accuracy:  0.5953678474114441
# precision:  0.7185354691075515
# recall:  0.6434426229508197
# f1:  0.6789189189189189
# ----------------------------------
# treshold 0.87
# length of dict before  482
# length of dict after  485
# new words  ['бендеровск', 'кацапск', 'член']
# accuracy:  0.5975609756097561
# precision:  0.7165532879818595
# recall:  0.6475409836065574
# f1:  0.6803013993541444
# ----------------------------------
# treshold 0.87
# length of dict before  485
# length of dict after  485
# new words  []
# accuracy:  0.5975609756097561
# precision:  0.7165532879818595
# recall:  0.6475409836065574
# f1:  0.6803013993541444
# ----------------------------------
# treshold 0.86
# length of dict before  485
# length of dict after  490
# new words  ['рот', 'жрат', 'хлеб', 'принцип', 'что']
# accuracy:  0.5911413969335605
# precision:  0.5057636887608069
# recall:  0.7192622950819673
# f1:  0.5939086294416244
# f1  0.6803013993541444 treshold  0.86 amount treshold  30
# -------------- TESTING SET RESULTS -----------
# accuracy:  0.6044776119402985
# precision:  0.51440329218107
# recall:  0.7530120481927711
# f1:  0.6112469437652812
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0.6112469437652812
