# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer("russian", ignore_stopwords=True)

# %%
bad_words = open('../data/bad_words.txt').read().split('\n')[:-1]

# %%
stemmed_dictionary = []
for word in bad_words:
    stemmed_dictionary.append(stemmer.stem(word))

# %%
stemmed_dictionary
# Out:
# ['6ля',
#  '6ляд',
#  '6лят',
#  'е6ал',
#  'еба',
#  'еба',
#  'ебыч',
#  'еба',
#  'ебет',
#  'еблант',
#  'xы',
#  'xы',
#  'xы',
#  'xу',
#  'xу',
#  'xу',
#  'архипиздр',
#  'ахуел',
#  'ахует',
#  'бзден',
#  'бздет',
#  'бздех',
#  'бздец',
#  'бздит',
#  'бздиц',
#  'бздло',
#  'бзднут',
#  'бздун',
#  'бздун',
#  'бздюх',
#  'бздюшк',
#  'бздюшк',
#  'бля',
#  'бляб',
#  'блябуд',
#  'бляд',
#  'бляд',
#  'блядин',
#  'блядищ',
#  'блядк',
#  'блядова',
#  'блядств',
#  'блядун',
#  'блядун',
#  'блядун',
#  'бляд',
#  'блядюг',
#  'блят',
#  'вафел',
#  'вафлер',
#  'взъебк',
#  'взьебк',
#  'взьебыва',
#  'въеб',
#  'въеба',
#  'въебен',
#  'въеб',
#  'въебыва',
#  'выблядок',
#  'выблядыш',
#  'выеб',
#  'выеба',
#  'выеб',
#  'выебнул',
#  'выебон',
#  'выебыва',
#  'выпердет',
#  'высра',
#  'высса',
#  'вьеб',
#  'гавн',
#  'гавнюк',
#  'гавнючк',
#  'гамн',
#  'гандон',
#  'гнид',
#  'гнид',
#  'гнид',
#  'говенк',
#  'говен',
#  'говешк',
#  'говназ',
#  'говнец',
#  'говнищ',
#  'говн',
#  'говноед',
#  'говнолинк',
#  'говночист',
#  'говнюк',
#  'говнюх',
#  'говнядин',
#  'говняк',
#  'говнян',
#  'говня',
#  'гондон',
#  'доебыва',
#  'долбоеб',
#  'долбоеб',
#  'долбоящер',
#  'дрисн',
#  'дрист',
#  'дристанут',
#  'дриста',
#  'дристун',
#  'дристух',
#  'дрочелл',
#  'дроч',
#  'дроч',
#  'дрочилк',
#  'дрочист',
#  'дроч',
#  'дрочк',
#  'дрочун',
#  'е6а',
#  'е6ут',
#  'еба',
#  'еба',
#  'ебыч',
#  'еба',
#  'еба',
#  'ебальник',
#  'еба',
#  'ебанама',
#  'ебанат',
#  'ебан',
#  'ебан',
#  'ебаническ',
#  'еба',
#  'ебанныйврот',
#  'ебан',
#  'ебанут',
#  'ебанут',
#  'ебан',
#  'ебан',
#  'ебаньк',
#  'ебар',
#  'ебат',
#  'ебат',
#  'ебатор',
#  'еба',
#  'еба',
#  'ебаш',
#  'еб',
#  'ебет',
#  'ебет',
#  'ебец',
#  'ебик',
#  'ебин',
#  'еб',
#  'ебическ',
#  'ебк',
#  'ебл',
#  'ебла',
#  'еблив',
#  'еблищ',
#  'ебл',
#  'еблыст',
#  'ебл',
#  'ебн',
#  'ебнут',
#  'ебнут',
#  'ебн',
#  'ебош',
#  'ебск',
#  'ебск',
#  'ебтвоюма',
#  'ебун',
#  'ебут',
#  'ебуч',
#  'ебуч',
#  'ебуч',
#  'ебуч',
#  'ебуч',
#  'ебущ',
#  'ебыр',
#  'елд',
#  'елдак',
#  'елдач',
#  'жоп',
#  'жоп',
#  'заговня',
#  'задрачива',
#  'задриста',
#  'задрот',
#  'зае6',
#  'зае6',
#  'заеб',
#  'заеб',
#  'заеб',
#  'заеба',
#  'заебанец',
#  'заебаст',
#  'заебаст',
#  'заеба',
#  'заеба',
#  'заебаш',
#  'заебист',
#  'заебист',
#  'заебист',
#  'заебист',
#  'заебист',
#  'заебист',
#  'заеб',
#  'заебош',
#  'заебыва',
#  'залуп',
#  'залуп',
#  'залупа',
#  'залуп',
#  'залуп',
#  'замудоха',
#  'запиздяч',
#  'засера',
#  'засерун',
#  'засер',
#  'засира',
#  'засрун',
#  'захуяч',
#  'заябест',
#  'злоеб',
#  'злоебуч',
#  'злоебуч',
#  'злоебуч',
#  'ибанамат',
#  'ибонех',
#  'изговня',
#  'изговня',
#  'изъебнут',
#  'ипа',
#  'ипа',
#  'ипацц',
#  'конч',
#  'курв',
#  'курвятник',
#  'лох',
#  'лошар',
#  'лошар',
#  'лошар',
#  'лошок',
#  'лярв',
#  'малаф',
#  'манд',
#  'мандавошек',
#  'мандавошк',
#  'мандавошк',
#  'манд',
#  'манден',
#  'мандет',
#  'мандищ',
#  'манд',
#  'манд',
#  'мандюк',
#  'минет',
#  'минетчик',
#  'минетчиц',
#  'млят',
#  'мокрощелк',
#  'мокрощелк',
#  'мраз',
#  'мудак',
#  'мудак',
#  'мудаг',
#  'мудак',
#  'муд',
#  'мудел',
#  'мудет',
#  'муд',
#  'муд',
#  'муд',
#  'мудист',
#  'мудн',
#  'мудоеб',
#  'мудозвон',
#  'мудокли^',
#  'набздел',
#  'набздет',
#  'наговня',
#  'надриста',
#  'надроч',
#  'наеба',
#  'наебет',
#  'наебнут',
#  'наебнут',
#  'наебыва',
#  'напиздел',
#  'напиздел',
#  'напиздел',
#  'напизд',
#  'насра',
#  'настопизд',
#  'нахер',
#  'нахр',
#  'нах',
#  'нахуйник',
#  'невротебуч',
#  'невъебен',
#  'нехир',
#  'нехр',
#  'нех',
#  'нехуйствен',
#  'ниибац',
#  'ниипацц',
#  'ниипацц',
#  'ниипет',
#  'нику',
#  'нихер',
#  'ниху',
#  'обдриста',
#  'обосранец',
#  'обосра',
#  'обосца',
#  'обосца',
#  'обсира',
#  'объебос',
#  'обьеба',
#  'обьебос',
#  'однохуйствен',
#  'опезда',
#  'опизд',
#  'опизденивающ',
#  'остоебен',
#  'остопиздет',
#  'отмудоха',
#  'отпизд',
#  'отпиздяч',
#  'отпорот',
#  'отъеб',
#  'охуевательск',
#  'охуева',
#  'охуева',
#  'охуел',
#  'охуен',
#  'охуеньчик',
#  'охует',
#  'охуительн',
#  'охуительн',
#  'охуяньчик',
#  'охуячива',
#  'охуяч',
#  'очкун',
#  'падл',
#  'падонк',
#  'падонок',
#  'паскуд',
#  'педерас',
#  'педик',
#  'педрик',
#  'педр',
#  'педрилл',
#  'педр',
#  'педрил',
#  'пезден',
#  'пезд',
#  'пезд',
#  'пезд',
#  'пезд',
#  'перданут',
#  'пердеж',
#  'перден',
#  'пердет',
#  'пердильник',
#  'перднут',
#  'перднут',
#  'пердун',
#  'пердунец',
#  'пердунин',
#  'пердун',
#  'пердух',
#  'перд',
#  'переебок',
#  'пернут',
#  'пернут',
#  'пи3д',
#  'пи3д',
#  'пи3д',
#  'пиздец',
#  'пидар',
#  'пидарас',
#  'пидарас',
#  'пидарас',
#  'пидар',
#  'пидор',
#  'пидорас',
#  'пидорк',
#  'пидорок',
#  'пидор',
#  'пидрас',
#  'пизд',
#  'пизданут',
#  'пизданут',
#  'пиздарваньчик',
#  'пиздат',
#  'пиздат',
#  'пиздат',
#  'пизденк',
#  'пизденыш',
#  'пизденыш',
#  'пиздет',
#  'пиздец',
#  'пизд',
#  'пизд',
#  'пизд',
#  'пизд',
#  'пиздищ',
#  'пиздищ',
#  'пиздобол',
#  'пиздобол',
#  'пиздобрат',
#  'пиздоват',
#  'пиздоват',
#  'пиздолиз',
#  'пиздонут',
#  'пиздорванец',
#  'пиздорванк',
#  'пиздострадател',
#  'пизд',
#  'пизд',
#  'пиздун',
#  'пиздун',
#  'пизд',
#  'пиздюг',
#  'пиздюк',
#  'пиздюлин',
#  'пиздюл',
#  'пизд',
#  'пиздяч',
#  'письк',
#  'писюн',
#  'писюшк',
#  'подговня',
#  'подонк',
#  'подонок',
#  'подъебнут',
#  'подъебнут',
#  'поеба',
#  'поебен',
#  'поебываа',
#  'поскуд',
#  'посра',
#  'потаскух',
#  'потаскушк',
#  'похер',
#  'похер',
#  'похер',
#  'похер',
#  'похер',
#  'похр',
#  'похрен',
#  'пох',
#  'похуист',
#  'похуистк',
#  'пох',
#  'придурок',
#  'приеба',
#  'припизден',
#  'припизднут',
#  'припиздюлин',
#  'пробздел',
#  'пробляд',
#  'проеб',
#  'проебанк',
#  'проеба',
#  'промандет',
#  'промудет',
#  'пропиздел',
#  'пропиздет',
#  'пропиздяч',
#  'раздолба',
#  'разхуяч',
#  'разъеб',
#  'разъеб',
#  'разъеба',
#  'разъеба',
#  'распизда',
#  'распиздет',
#  'распиздя',
#  'распиздяйств',
#  'распроет',
#  'сволот',
#  'сволоч',
#  'сговня',
#  'секел',
#  'серун',
#  'серьк',
#  'сестроеб',
#  'сикел',
#  'сира',
#  'сирыва',
#  'сос',
#  'спиздел',
#  'спиздет',
#  'спизд',
#  'спизд',
#  'спизд',
#  'спизд',
#  'спизд',
#  'срак',
#  'срак',
#  'сран',
#  'сран',
#  'срат',
#  'срун',
#  'ссак',
#  'ссыш',
#  'стерв',
#  'страхопиздищ',
#  'сук',
#  'сук',
#  'суходрочк',
#  'сучар',
#  'суч',
#  'сучк',
#  'сучк',
#  'сучонок',
#  'суч',
#  'сцан',
#  'сцат',
#  'сцук',
#  'сцук',
#  'сцукон',
#  'сцул',
#  'сцых',
#  'сцыш',
#  'съеба',
#  'сыкун',
#  'трахае6',
#  'трахаеб',
#  'трахаеб',
#  'трахател',
#  'ублюдок',
#  'уеба',
#  'уебищ',
#  'уебищ',
#  'уебищ',
#  'уебищн',
#  'уебищн',
#  'уебк',
#  'уебк',
#  'уебк',
#  'уебок',
#  'уебок',
#  'урюк',
#  'усра',
#  'ушлепок',
#  'хы',
#  'хы',
#  'хыйн',
#  'хамл',
#  'хер',
#  'херн',
#  'хероват',
#  'херовин',
#  'херов',
#  'хитровыеба',
#  'хитрожоп',
#  'ху',
#  'ху',
#  'ху',
#  'хуеват',
#  'хуевеньк',
#  'хуевин',
#  'хуев',
#  'хуев',
#  'хуев',
#  'хуек',
#  'хуек',
#  'хуел',
#  'ху',
#  'хуенч',
#  'хуеныш',
#  'хуеньк',
#  'хуеплет',
#  'хуеплет',
#  'хуепромышленник',
#  'хуерик',
#  'хуер',
#  'хуесос',
#  'хуесоск',
#  'хует',
#  'хуетен',
#  'ху',
#  'ху',
#  'ху',
#  'хуйк',
#  'хуйл',
#  'хуйн',
#  'хуйрик',
#  'хуищ',
#  'хул',
#  'ху',
#  'хуюл',
#  'ху',
#  'хуяк',
#  'хуяка',
#  'хуякнут',
#  'хуяр',
#  'хуяс',
#  'хуяч',
#  'целк',
#  'чмо',
#  'чмошник',
#  'чмыр',
#  'шалав',
#  'шалав',
#  'шараеб',
#  'шлюх',
#  'шлюх',
#  'шлюшк',
#  'ябыва',
#  'пидар',
#  'сцыкун',
#  'долбаеб',
#  'долбаеб',
#  'гомосек',
#  'гомосек',
#  'гандон',
#  'гандон',
#  'урод',
#  'урод',
#  'петух',
#  'бара',
#  'пипец',
#  'быдл']

# %%
stemmer.stem('хохлятских')
# Out:
# 'хохлятск'

# %%
if 'хуй' in 'хуй':
    print('aaaa')
# Out:
# aaaa
